# %%
# import dependencies
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("heartdisease.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6aa3406215f7> in <cell line: 1>()
# ----> 1 df=pd.read_csv("heartdisease.csv")
#
# NameError: name 'pd' is not defined

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0

# %%
#Barplot using seaborn 
sns.barplot(x='sex',y='thalach',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='thalach'>

# %%
sns.scatterplot(x='sex',y='thalach',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='thalach'>

# %%
sns.lineplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#pairplot using seaborn library

sns.pairplot(df, hue='sex', palette='Blues')

# %%
#Displot using seaborn 
sns.displot(df['thalach'])

# %%
#scatterplot using matplotlib
plt.scatter(df['thalach'],df['age'])
plt.show()

# %%
#Scatterplot using matplotlib
plt.scatter(df['thalach'],df['age'])
plt.show()

# %%
sex_df = pd.DataFrame(df['sex'].value_counts())
sex_df
# Out:
#    sex
# 1  206
# 0   97

# %%
plt.pie(sex_df['sex'],label = sex_df.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9dae198fcdb5> in <cell line: 1>()
# ----> 1 plt.pie(sex_df['sex'],label = sex_df.index)
#
# TypeError: pie() got an unexpected keyword argument 'label'
